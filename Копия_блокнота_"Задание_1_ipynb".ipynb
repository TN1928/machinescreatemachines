# %% [markdown]
# <a href="https://colab.research.google.com/github/TN1928/machinescreatemachines/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_1_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 1

# %% [markdown]
# ##Загрузка датасета
# В файле classification datasets расположены ссылки на датасеты. Выберите один в соответствии со своим вариантом, скачайте и прочитайте файл
#
# **Не забудьте загрузить нужные библиотеки**
#
# Например: pip3 install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/crimes_against_women_2001-2014.csv")

# %% [markdown]
# ##Первое знакомство с датасетом
# В следующих ячейках выведите:
#
#
# 1.   Колонки датасета
# 2.   Первые 5 значений
# 3.   Последние 5 значений
# 4.   Статистику по числовым колонкам

# %%
df.columns #Колонки
# Out:
# Index(['Unnamed: 0', 'STATE/UT', 'DISTRICT', 'Year', 'Rape',
#        'Kidnapping and Abduction', 'Dowry Deaths',
#        'Assault on women with intent to outrage her modesty',
#        'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
#        'Importation of Girls'],
#       dtype='object')

# %%
df[:5]#Первые 5 значений
# Out:
#    Unnamed: 0        STATE/UT       DISTRICT  Year  Rape  \
# 0           0  ANDHRA PRADESH       ADILABAD  2001    50
# 1           1  ANDHRA PRADESH      ANANTAPUR  2001    23
# 2           2  ANDHRA PRADESH       CHITTOOR  2001    27
# 3           3  ANDHRA PRADESH       CUDDAPAH  2001    20
# 4           4  ANDHRA PRADESH  EAST GODAVARI  2001    23
#
#    Kidnapping and Abduction  Dowry Deaths  \
# 0                        30            16
# 1                        30             7
# 2                        34            14
# 3                        20            17
# 4                        26            12
#
#    Assault on women with intent to outrage her modesty  \
# 0                                                149
# 1                                                118
# 2                                                112
# 3                                                126
# 4                                                109
#
# ...

# %%
df.tail(5)#Последние 5 значений
# Out:
#        Unnamed: 0     STATE/UT           DISTRICT  Year  Rape  \
# 10672         832  Lakshadweep        Lakshadweep  2014     1
# 10673         833  Lakshadweep  Total District(s)  2014     1
# 10674         834   Puducherry           Karaikal  2014     3
# 10675         835   Puducherry         Puducherry  2014     7
# 10676         836   Puducherry  Total District(s)  2014    10
#
#        Kidnapping and Abduction  Dowry Deaths  \
# 10672                         0             0
# 10673                         0             0
# 10674                         1             0
# 10675                         6             1
# 10676                         7             1
#
#        Assault on women with intent to outrage her modesty  \
# 10672                                                  1
# 10673                                                  1
# 10674                                                 12
# 10675                                                 20
# ...

# %%
df.describe() #Статистику
# Out:
#          Unnamed: 0          Year          Rape  Kidnapping and Abduction  \
# count  10677.000000  10677.000000  10677.000000              10677.000000
# mean    3871.570198   2007.697949     57.989885                 69.888358
# std     2816.369918      4.046874    214.230398                311.623450
# min        0.000000   2001.000000      0.000000                  0.000000
# 25%     1009.000000   2004.000000      8.000000                  6.000000
# 50%     3678.000000   2008.000000     22.000000                 20.000000
# 75%     6347.000000   2011.000000     44.000000                 49.000000
# max     9016.000000   2014.000000   5076.000000              10626.000000
#
#        Dowry Deaths  Assault on women with intent to outrage her modesty  \
# count  10677.000000                                       10677.000000
# mean      20.181699                                         113.539196
# std       98.276531                                         458.903951
# ...

# %% [markdown]
# **Ответьте на следующие вопросы:**
#
#
# 1.   Какие средние значения в каждой числовой колонке вашего датасета?
# 2.   Минимальные и максимальные значения в каждой числовой колонке вашего датасета

# %% [markdown]
# 1.   **Ответ 1.** 3871.570198	2007.697949	57.989885	69.888358	20.181699	113.539196	27.419313	209.224314	0.175330
# 2.   **Ответ 2.** min	0.000000	2001.000000	0.000000	0.000000	0.000000	0.000000	0.000000	0.000000	0.000000
#
# max	9016.000000	2014.000000	5076.000000	10626.000000	2469.000000	10001.000000	4970.000000	23278.000000	83.000000

# %% [markdown]
# ##Типизация
# Присвойте соответствующим колонкам один из типов (category, float, int)

# %%
df.Year = df.Year.astype("int")
df.DISTRICT = df.DISTRICT.astype("category")


#Вывести типы колонок тут
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10677 entries, 0 to 10676
# Data columns (total 11 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Unnamed: 0                                           10677 non-null  int64
#  1   STATE/UT                                             10677 non-null  object
#  2   DISTRICT                                             10677 non-null  category
#  3   Year                                                 10677 non-null  int64
#  4   Rape                                                 10677 non-null  int64
#  5   Kidnapping and Abduction                             10677 non-null  int64
#  6   Dowry Deaths                                         10677 non-null  int64
#  7   Assault on women with intent to outrage her modesty  10677 non-null  int64
# ...

# %% [markdown]
# Какие признаки вы можете выделить в своем датасете (категориальные, числовые и др., **минимум 3 разных**, помните что можно также выделить признаки более точно, например числовые - порядковые, количественные и т.д.)?
#
# DISTRICT - категория;
# Year и Rape - численные

# %% [markdown]
# ##Фильтрация
# Офильтруйте 3 колонки вашего датасета и выведите результат

# %%
df[df["Dowry Deaths"] < 5]


#Фильтр колонки 1
# Out:
#        Unnamed: 0        STATE/UT           DISTRICT  Year  Rape  \
# 5               5  ANDHRA PRADESH      GUNTAKAL RLY.  2001     0
# 19             19  ANDHRA PRADESH  SECUNDERABAD RLY.  2001     0
# 21             21  ANDHRA PRADESH         VIJAYAWADA  2001    25
# 22             22  ANDHRA PRADESH    VIJAYAWADA RLY.  2001     1
# 23             23  ANDHRA PRADESH      VISAKHA RURAL  2001    12
# ...           ...             ...                ...   ...   ...
# 10672         832     Lakshadweep        Lakshadweep  2014     1
# 10673         833     Lakshadweep  Total District(s)  2014     1
# 10674         834      Puducherry           Karaikal  2014     3
# 10675         835      Puducherry         Puducherry  2014     7
# 10676         836      Puducherry  Total District(s)  2014    10
#
#        Kidnapping and Abduction  Dowry Deaths  \
# 5                             0             0
# 19                            0             1
# ...

# %%
df[df["Year"] < 2002]

#Фильтр колонки 2
# Out:
#      Unnamed: 0        STATE/UT       DISTRICT  Year  Rape  \
# 0             0  ANDHRA PRADESH       ADILABAD  2001    50
# 1             1  ANDHRA PRADESH      ANANTAPUR  2001    23
# 2             2  ANDHRA PRADESH       CHITTOOR  2001    27
# 3             3  ANDHRA PRADESH       CUDDAPAH  2001    20
# 4             4  ANDHRA PRADESH  EAST GODAVARI  2001    23
# ..          ...             ...            ...   ...   ...
# 711         711           DELHI           WEST  2001    45
# 712         712     LAKSHADWEEP    LAKSHADWEEP  2001     0
# 713         713     LAKSHADWEEP          TOTAL  2001     0
# 714         714      PUDUCHERRY    PONDICHERRY  2001     9
# 715         715      PUDUCHERRY          TOTAL  2001     9
#
#      Kidnapping and Abduction  Dowry Deaths  \
# 0                          30            16
# 1                          30             7
# 2                          34            14
# 3                          20            17
# ...

# %%
df[df["Kidnapping and Abduction"] > 100]

#Фильтр колонки 3
# Out:
#        Unnamed: 0        STATE/UT           DISTRICT  Year  Rape  \
# 28             28  ANDHRA PRADESH              TOTAL  2001   871
# 64             64           ASSAM             NAGAON  2001    51
# 70             70           ASSAM              TOTAL  2001   817
# 115           115           BIHAR              TOTAL  2001   888
# 135           135    CHHATTISGARH              TOTAL  2001   959
# ...           ...             ...                ...   ...   ...
# 10664         824        Delhi UT              South  2014   280
# 10665         825        Delhi UT         South-East  2014   266
# 10666         826        Delhi UT         South-West  2014   234
# 10670         830        Delhi UT               West  2014   251
# 10671         831        Delhi UT  Total District(s)  2014  2096
#
#        Kidnapping and Abduction  Dowry Deaths  \
# 28                          765           420
# 64                          109             1
# ...

# %% [markdown]
# ##Группировка
# Сгруппируйте датасет по какому-либо категориальному признаку и выведите среднее значение численных колонок (см. метод mean в pandas)

# %%
df.groupby('STATE/UT').mean(numeric_only=True)

#Группировка
# Out:
#                     Unnamed: 0         Year        Rape  \
# STATE/UT
# A & N ISLANDS      4866.861111  2006.638889    6.055556
# A & N Islands       802.500000  2014.000000   16.000000
# A&N Islands         789.500000  2013.000000   13.500000
# ANDHRA PRADESH     4180.410811  2006.672973   72.859459
# ARUNACHAL PRADESH  4263.415385  2006.753846    5.128205
# ...                        ...          ...         ...
# UTTARAKHAND        4724.166667  2006.500000   16.404762
# Uttar Pradesh       711.000000  2013.500000   84.636364
# Uttarakhand         756.500000  2013.500000   35.571429
# WEST BENGAL        4807.394822  2006.582524  134.543689
# West Bengal         778.852459  2013.508197  103.311475
#
#                    Kidnapping and Abduction  Dowry Deaths  \
# STATE/UT
# A & N ISLANDS                      4.277778      0.333333
# A & N Islands                      8.500000      1.500000
# A&N Islands                        6.000000      0.500000
# ...

# %% [markdown]
# ##Задание для гениев *
# Агрегируйте числовой признак по категориальному признаку с использованием метода **без использования** библиотеки pandas, и вычислите медиану и среднее значение для каждой категории.

# %%
#Агрегация
